# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("Dr. wants to test doctor. Here we have apple, banana, etc. and much more")

for sentence in doc.sents:
    print(sentence)
# Out:
# Dr. wants to test doctor.
# Here we have apple, banana, etc. and much more

# %%
for sentence in doc.sents:
    for word in sentence:
        print(word)
# Out:
# Dr.
# wants
# to
# test
# doctor
# .
# Here
# we
# have
# apple
# ,
# banana
# ,
# etc
# .
# and
# much
# more

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
sent_tokenize("Dr. wants to test doctor. Here we have apple, banana, etc. and much more",language="english")
# Out:
# ['Dr. wants to test doctor.',
#  'Here we have apple, banana, etc.',
#  'and much more']

# %%
word_tokenize("Dr. wants to test doctor. Here we have apple, banana, etc. and much more",language="english")
# Out:
# ['Dr.',
#  'wants',
#  'to',
#  'test',
#  'doctor',
#  '.',
#  'Here',
#  'we',
#  'have',
#  'apple',
#  ',',
#  'banana',
#  ',',
#  'etc',
#  '.',
#  'and',
#  'much',
#  'more']

# %% [markdown]
# ### Tokenisation using Spacy

# %%
import spacy

# %%
nlp = spacy.blank('en')
doc = nlp("""Dear Team,

We are excited to announce the final schedule for our annual conference. A huge thanks to everyone who contributed, especially john.doe@example.com and jane_smith@company.org, for their excellent input. As we finalize the logistics, please reach out to support@services.co for any technical queries or issues related to the event platform. 

For academic collaborations, contact alice.brown@university.edu, who will be coordinating with guest speakers. Marketing initiatives are already in full swing, so ensure you sync up with marketing_team@business.com for any promotional materials or updates on social media campaigns. Additionally, the CEO, reachable at ceo@startup.inc, has asked for a concise summary of all key projects by Friday.

If there are any HR-related questions, such as travel arrangements or reimbursement policies, send an email to hr_department@organization.net. Also, for any inquiries related to the event website, info123@platform.io is your go-to contact. We've received positive feedback from our beta testers—if you have any suggestions or further comments, email feedback@userportal.us.

Our sales department is working closely with sponsors to ensure a smooth experience for all participants. Sales inquiries should be sent to sales@ecommerce.biz. On the technical side, the engineering team (engineering@techhub.ai) has successfully completed the app's integration with our existing platforms. Kudos to them for their hard work!

As we gear up for the event, administrative tasks are crucial. Admin-related questions can be directed to admin@onlineplatform.cloud. If you’re reaching out to solution providers or seeking partnerships, contact@solutions.company is managing those communications. Remember, customer service representatives (customer_service@brand.co.uk) will be available 24/7 during the event to assist attendees.

Finally, if you have any general inquiries, send them to inquiries@domain.ca. We aim to provide a seamless experience for everyone involved, so do not hesitate to share any concerns.

To reiterate:
- Use the designated email addresses for efficient communication.
- Keep cc’ing the relevant departments for visibility.

Let’s make this conference a huge success!

Best regards,  
The Organizing Committee
""")
emails = []

# %%
for token in doc:
    if token.like_email:
        emails.append(token)

# %%
for email in emails:
    print(email)
# Out:
# john.doe@example.com
# jane_smith@company.org
# support@services.co
# alice.brown@university.edu
# marketing_team@business.com
# ceo@startup.inc
# hr_department@organization.net
# info123@platform.io
# feedback@userportal.us
# sales@ecommerce.biz
# engineering@techhub.ai
# admin@onlineplatform.cloud
# contact@solutions.company
# customer_service@brand.co.uk
# inquiries@domain.ca

# %%
nlp = spacy.blank('en')

# %%
from spacy.symbols import ORTH
nlp.tokenizer.add_special_case("gimme",[
    {ORTH:"gim"},
    {ORTH:"me"}
])

# %%
doc = nlp("""gimme this text""")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gim', 'me', 'this', 'text']

# %%
doc = nlp("This is first sentence. This is second sentence.")

print(nlp.pipe_names)
nlp.add_pipe('sentencizer')
print(nlp.pipe_names)
# Out:
# ['sentencizer']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 4
#       1 doc = nlp("This is first sentence. This is second sentence.")
#       3 print(nlp.pipe_names)
# ----> 4 nlp.add_pipe('sentencizer')
#       5 print(nlp.pipe_names)
#
# File c:\Users\Friends Com\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\language.py:813, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     811 name = name if name is not None else factory_name
#     812 if name in self.component_names:
# --> 813     raise ValueError(Errors.E007.format(name=name, opts=self.component_names))
#     814 # Overriding pipe name in the config is not supported and will be ignored.
#     815 if "name" in config:
#
# ValueError: [E007] 'sentencizer' already exists in pipeline. Existing names: ['sentencizer']

# %%
for sentence in doc.sents:
    print(sentence)
# Out:
# This is first sentence.
# This is second sentence.

# %% [markdown]
# ### Exercise

# %%
doc = nlp("""Look for data to help you address the question. Governments are good
sources because data from public research is often freely available. Good
places to start include http://www.data.gov/, and http://www.science.
gov/, and in the United Kingdom, http://data.gov.uk/.
Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/, 
and the European Social Survey at http://www.europeansocialsurvey.org/.""")

# %%
urls = []
for token in doc:
    if token.like_url:
        urls.append(token)
urls
# Out:
# [http://www.data.gov/,
#  http://www.science,
#  http://data.gov.uk/.,
#  http://www3.norc.org/gss+website/,
#  http://www.europeansocialsurvey.org/.]

# %%
doc = nlp('''Tony gave two $ to Peter 3 days back, Bruce gave 500 € to Steve''')

transactions = []

for token in doc:
    if token.like_num and doc[token.i+1].is_currency:
        transactions.append(f"{token} {doc[token.i+1]}")

print(transactions)
# Out:
# ['two $', '500 €']
