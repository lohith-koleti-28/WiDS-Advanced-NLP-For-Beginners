# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp("This is a string made using keyboard which is material energy of Krishna")
for token in doc:
    print(token," | ",token.pos_, " | ", token.tag_, " | ", spacy.explain(token.tag_))
# Out:
# This  |  PRON  |  DT  |  determiner
# is  |  AUX  |  VBZ  |  verb, 3rd person singular present
# a  |  DET  |  DT  |  determiner
# string  |  NOUN  |  NN  |  noun, singular or mass
# made  |  VERB  |  VBN  |  verb, past participle
# using  |  VERB  |  VBG  |  verb, gerund or present participle
# keyboard  |  NOUN  |  NN  |  noun, singular or mass
# which  |  PRON  |  WDT  |  wh-determiner
# is  |  AUX  |  VBZ  |  verb, 3rd person singular present
# material  |  ADJ  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# energy  |  NOUN  |  NN  |  noun, singular or mass
# of  |  ADP  |  IN  |  conjunction, subordinating or preposition
# Krishna  |  PROPN  |  NNP  |  noun, proper singular

# %%
doc = nlp("""Microsoft Corp. today announced the following results for the quarter ended June 30, 2024, as compared to the corresponding period of last fiscal year:

·        Revenue was $64.7 billion and increased 15% (up 16% in constant currency)

·        Operating income was $27.9 billion and increased 15% (up 16% in constant currency)

·        Net income was $22.0 billion and increased 10% (up 11% in constant currency)

·        Diluted earnings per share was $2.95 and increased 10% (up 11% in constant currency)

“Our strong performance this fiscal year speaks both to our innovation and to the trust customers continue to place in Microsoft," said Satya Nadella, chairman and chief executive officer of Microsoft. “As a platform company, we are focused on meeting the mission-critical needs of our customers across our at-scale platforms today, while also ensuring we lead the AI era.”

“We closed out our fiscal year with a solid quarter, highlighted by record bookings and Microsoft Cloud quarterly revenue of $36.8 billion, up 21% (up 22% in constant currency) year-over-year,” said Amy Hood, executive vice president and chief financial officer of Microsoft.""")

text = []
for token in doc:
    if (token.pos_ in ["PUNCT","X","SPACE"]):
        text.append(token)

text
# Out:
# [,,
#  ,,
#  :,
#
#  ,
#  ·,
#         ,
#  (,
#  ),
#
#  ,
#  ·,
#         ,
#  (,
#  ),
#
#  ,
#  ·,
#         ,
#  (,
#  ),
#
#  ,
#  ·,
#         ,
#  (,
#  ),
#
#  ,
#  “,
#  ,,
#  ",
#  ,,
#  .,
#  “,
#  ,,
#  -,
#  -,
#  ,,
#  .,
#  ”,
#
#  ,
#  “,
#  ,,
#  ,,
#  (,
#  ),
#  -,
#  -,
#  ,,
#  ”,
#  ,,
#  .]

# %% [markdown]
# ### Exercise

# %%
doc = nlp("""Inflation rose again in April, continuing a climb that has pushed consumers to the brink and is threatening the economic expansion, the Bureau of Labor Statistics reported Wednesday.

The consumer price index, a broad-based measure of prices for goods and services, increased 8.3% from a year ago, higher than the Dow Jones estimate for an 8.1% gain. That represented a slight ease from March’s peak but was still close to the highest level since the summer of 1982.

Removing volatile food and energy prices, so-called core CPI still rose 6.2%, against expectations for a 6% gain, clouding hopes that inflation had peaked in March.

The month-over-month gains also were higher than expectations — 0.3% on headline CPI versus the 0.2% estimate and a 0.6% increase for core, against the outlook for a 0.4% gain.

The price gains also meant that workers continued to lose ground. Real wages adjusted for inflation decreased 0.1% on the month despite a nominal increase of 0.3% in average hourly earnings. Over the past year, real earnings have dropped 2.6% even though average hourly earnings are up 5.5%.

Inflation has been the single biggest threat to a recovery that began early in the Covid pandemic and saw the economy in 2021 stage its biggest single-year growth level since 1984. Rising prices at the pump and in grocery stores have been one problem, but inflation has spread beyond those two areas into housing, auto sales and a host of other areas.

Federal Reserve officials have responded to the problem with two interest rate hikes so far this year and pledges of more until inflation comes down to the central bank’s 2% goal. However, Wednesday’s data shows that the Fed has a big job ahead.

Credits: cnbc.com""")

nouns = []
nums = []

for token in doc:
    if token.pos_ == "NOUN":
        nouns.append(token)
    elif token.pos_ == "NUM":
        nums.append(token)

print("Nouns: ",nouns)
print("Numbers: ",nums)
# Out:
# Nouns:  [Inflation, climb, consumers, brink, expansion, consumer, price, index, measure, prices, goods, services, %, year, estimate, %, gain, ease, peak, level, summer, food, energy, prices, core, %, expectations, %, gain, hopes, inflation, month, month, gains, expectations, %, headline, %, estimate, %, increase, core, outlook, %, gain, price, gains, workers, ground, wages, inflation, %, month, increase, %, earnings, year, earnings, %, earnings, %, Inflation, threat, recovery, pandemic, economy, stage, year, growth, level, prices, pump, grocery, stores, problem, inflation, areas, housing, auto, sales, host, areas, officials, problem, interest, rate, hikes, year, pledges, inflation, bank, %, goal, data, job, Credits]
# Numbers:  [8.3, 8.1, 1982, 6.2, 6, 0.3, 0.2, 0.6, 0.4, 0.1, 0.3, 2.6, 5.5, 2021, 1984, one, two, two, 2]

# %%
count = doc.count_by(spacy.attrs.POS)

for k,v in count.items():
    print(doc.vocab[k].text," | ",v)
# Out:
# NOUN  |  96
# VERB  |  27
# ADV  |  15
# ADP  |  39
# PROPN  |  16
# PUNCT  |  32
# DET  |  34
# PRON  |  4
# AUX  |  13
# CCONJ  |  10
# ADJ  |  23
# SPACE  |  7
# NUM  |  19
# PART  |  4
# SCONJ  |  8
# X  |  1

# %% [markdown]
# ## Named Entity Recognition

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp("This is a text file for some simple analysis using Spacy for NLP purpose.")

for ent in doc.ents:
    print(ent.text,"|", ent.label_)
print("")
for token in doc:
    print(token,"|",token.tag_, "|",token.pos_)
# Out:
# Spacy | PERSON
# NLP | ORG
#
# This | DT | PRON
# is | VBZ | AUX
# a | DT | DET
# text | NN | NOUN
# file | NN | NOUN
# for | IN | ADP
# some | DT | DET
# simple | JJ | ADJ
# analysis | NN | NOUN
# using | VBG | VERB
# Spacy | NNP | PROPN
# for | IN | ADP
# NLP | NNP | PROPN
# purpose | NN | NOUN
# . | . | PUNCT

# %%
from spacy import displacy

displacy.render(doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">This is a text file for some simple analysis using
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spacy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  purpose.</div></span>

# %%
from spacy.tokens import Span

doc = nlp("Tesla is going to acquire Twitter in $4 billions")
s1 = Span(doc,0,1,label="ORG")
s2 = Span(doc,5,6,label="ORG")

for ent in doc.ents:
    print(ent.text,"|", ent.label_)

doc.set_ents([s1,s2],default='unmodified')
print()
for ent in doc.ents:
    print(ent.text,"|", ent.label_)
# Out:
# Tesla | ORG
# Twitter | PERSON
# $4 billions | MONEY
#
# Tesla | ORG
# Twitter | ORG
# $4 billions | MONEY

# %% [markdown]
# ### Exercise

# %%
doc = nlp("""Kiran want to know the famous foods in each state of India. So, he opened Google and search for this question. Google showed that
in Delhi it is Chaat, in Gujarat it is Dal Dhokli, in Tamilnadu it is Pongal, in Andhrapradesh it is Biryani, in Assam it is Papaya Khar,
in Bihar it is Litti Chowkha and so on for all other states""")

geo_locs = []

for ent in doc.ents:
    if ent.label_ == "GPE":
        geo_locs.append(ent)

print("Geographical Location Names",geo_locs)
# Out:
# Geographical Location Names [Kiran, India, Delhi, Gujarat, Tamilnadu, Andhrapradesh, Assam, Bihar]

# %%
doc = nlp("""Sachin Tendulkar was born on 24 April 1973, Virat Kholi was born on 5 November 1988, Dhoni was born on 7 July 1981
and finally Ricky ponting was born on 19 December 1974.""")

dates = []
for ent in doc.ents:
    if ent.label_== "DATE":
        dates.append(ent)

print(dates,len(dates))
# Out:
# [24 April 1973, 5 November 1988, 7 July 1981, 19 December 1974] 4
