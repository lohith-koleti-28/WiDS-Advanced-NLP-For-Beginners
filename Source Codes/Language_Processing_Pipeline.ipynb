# %%
import spacy
nlp = spacy.load('en_core_web_sm')
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc = nlp('''Google was founded by Larry Page and Sergey Brin while they were Ph.D. students at Stanford University in 1998. 
The company, headquartered in Mountain View, California, has grown to become one of the largest technology companies in the world, with a market capitalization exceeding $1 trillion in 2023.''')
for token in doc.ents:
    print(token, " | ", token.label_," | ",spacy.explain(token.label_))
# Out:
# Google  |  ORG  |  Companies, agencies, institutions, etc.
# Larry Page  |  PERSON  |  People, including fictional
# Sergey Brin  |  PERSON  |  People, including fictional
# Ph.D.  |  WORK_OF_ART  |  Titles of books, songs, etc.
# Stanford University  |  ORG  |  Companies, agencies, institutions, etc.
# 1998  |  DATE  |  Absolute or relative dates or periods
# Mountain View  |  GPE  |  Countries, cities, states
# California  |  GPE  |  Countries, cities, states
# $1 trillion  |  MONEY  |  Monetary values, including unit
# 2023  |  DATE  |  Absolute or relative dates or periods

# %%
from spacy import displacy

displacy.render(doc,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was founded by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Larry Page
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sergey Brin
# ...

# %%
displacy.render(nlp("Mr. Bloomberg founded a data analytics company Bloomberg"),style='ent')
# This wont work with a blank pipeline
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  founded a data analytics company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>

# %% [markdown]
# ### Exercise

# %%
doc = nlp('''Ravi and Raju are the best friends from school days.They wanted to go for a world tour and 
visit famous cities like Paris, London, Dubai, Rome etc and also they called their another friend Mohan to take part of this world tour.
They started their journey from Hyderabad and spent next 3 months travelling all the wonderful cities in the world and cherish a happy moments!''')

prop_nouns = []

for token in doc:
    if token.pos_ == 'PROPN':
        prop_nouns.append(token)

print(prop_nouns, len(prop_nouns))
# Out:
# [Raju, Paris, London, Dubai, Rome, Mohan, Hyderabad] 7

# %%
doc = nlp('''The Top 5 companies in USA are Tesla, Walmart, Amazon, Microsoft, Google and the top 5 companies in 
India are Infosys, Reliance, HDFC Bank, Hindustan Unilever and Bharti Airtel''')

companies = []

for token in doc.ents:
    if token.label_ == 'ORG':
        companies.append(token)

print(companies,len(companies))
# Out:
# [Tesla, Walmart, Amazon, Microsoft, Google, Infosys, Reliance, HDFC Bank, Hindustan Unilever, Bharti Airtel] 10

# %%
doc = nlp('''Jeff Bezos founded Amazon in 1994, revolutionizing the e-commerce industry. 
          Meanwhile, Bill Gates and Paul Allen co-founded Microsoft, which became a leader in software development. 
          Recently, Elon Musk's SpaceX has gained significant attention for its advancements in space exploration.''')

persons = []
orgs = []

for token in doc.ents:
    if token.label_ == 'PERSON':
        persons.append(token)
    elif token.label_ == "ORG":
        orgs.append(token)

print(f"Persons: {persons} | Number of Entities: {len(persons)}\nOrganisations: {orgs} | Number of Entities: {len(orgs)}")
# Out:
# Persons: [Jeff Bezos, Bill Gates, Paul Allen, Elon Musk's] | Number of Entities: 4
# Organisations: [Amazon, Microsoft] | Number of Entities: 2
